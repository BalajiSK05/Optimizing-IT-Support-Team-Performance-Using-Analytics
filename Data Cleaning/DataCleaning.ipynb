# %%
import pandas as pd
df=pd.read_excel('cleaning.xlsx')
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter        White          NaN
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger          NaN
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN           Na
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee          NaN
# 11        1012      Harry       Potter          NaN
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter        White          NaN
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger          NaN
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN           Na
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee          NaN
# 11        1012      Harry       Potter          NaN
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# ...

# %%
df["Last_Name"] = df["Last_Name"].str.strip("/.")
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter        White          NaN
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger          NaN
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN           Na
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee          NaN
# 11        1012      Harry       Potter          NaN
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace("-", "" )
df["Phone_Number"] = df["Phone_Number"].str.replace("/", "" )
df["Phone_Number"] = df["Phone_Number"].str.replace("|", "" )
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter        White          NaN
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger          NaN
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN           Na
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee          NaN
# 11        1012      Harry       Potter          NaN
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes", "Y" )
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("No", "N" )
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter        White          NaN
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger          NaN
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN           Na
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee          NaN
# 11        1012      Harry       Potter          NaN
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace("Yes", "Y" )
df["Paying Customer"] = df["Paying Customer"].str.replace("No", "N" )
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 2         1003     Walter        White          NaN
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 6         1007       Jeff       Winger          NaN
# 7         1008   Sherlock       Holmes   8766783469
# 8         1009    Gandalf          NaN           Na
# 9         1010      Peter       Parker   1235455421
# 10        1011    Samwise       Gamgee          NaN
# 11        1012      Harry       Potter          NaN
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# ...

# %%
df = df.dropna()
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 7         1008   Sherlock       Holmes   8766783469
# 9         1010      Peter       Parker   1235455421
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# 18        1019      Creed       Braton           Na
# 19        1020     Anakin    Skywalker   8766783469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire               Y              N
# ...

# %%
df = df.dropna()
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 7         1008   Sherlock       Holmes   8766783469
# 9         1010      Peter       Parker   1235455421
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# 18        1019      Creed       Braton           Na
# 19        1020     Anakin    Skywalker   8766783469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire               Y              N
# ...

# %%
import pandas as pd
df = pd.read_excel('cleaning.xlsx')
df = df.drop_duplicates()
df["Last_Name"] = df["Last_Name"].str.strip("/.")
df["Phone_Number"] = df["Phone_Number"].str.replace("-", "" )
df["Phone_Number"] = df["Phone_Number"].str.replace("/", "" )
df["Phone_Number"] = df["Phone_Number"].str.replace("|", "" )
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes", "Y" )
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("No", "N" )
df["Paying Customer"] = df["Paying Customer"].str.replace("Yes", "Y" )
df["Paying Customer"] = df["Paying Customer"].str.replace("No", "N" )
df = df.dropna()
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins   1235455421
# 1         1002       Abed        Nadir   1236439775
# 3         1004     Dwight      Schrute   1235432345
# 4         1005        Jon         Snow   8766783469
# 5         1006        Ron      Swanson   3047622467
# 7         1008   Sherlock       Holmes   8766783469
# 9         1010      Peter       Parker   1235455421
# 12        1013        Don       Draper   1235432345
# 13        1014     Leslie        Knope   8766783469
# 14        1015       Toby  Flenderson_   3047622467
# 15        1016        Ron      Weasley   1235455421
# 16        1017   Michael         Scott   1236439775
# 18        1019      Creed       Braton           Na
# 19        1020     Anakin    Skywalker   8766783469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire               Y              N
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('cleaning.xlsx')

# Convert known string representations of nulls to np.nan for consistent handling by dropna()
df.replace({'N/a': np.nan, 'nan': np.nan, '': np.nan}, inplace=True)

df = df.drop_duplicates()

# Apply existing Last_Name cleaning (strip / and . and leading/trailing whitespace)
df["Last_Name"] = df["Last_Name"].astype(str).str.strip("/. ")

# Apply Phone_Number cleaning
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("-", "" )
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("/", "" )
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("|", "" )

# Apply Do_Not_Contact cleaning
df["Do_Not_Contact"] = df["Do_Not_Contact"].astype(str).str.replace("Yes", "Y" )
df["Do_Not_Contact"] = df["Do_Not_Contact"].astype(str).str.replace("No", "N" )

# Apply Paying Customer cleaning
df["Paying Customer"] = df["Paying Customer"].astype(str).str.replace("Yes", "Y" )
df["Paying Customer"] = df["Paying Customer"].astype(str).str.replace("No", "N" )

# Perform the current subtask: remove all rows containing null values
df = df.dropna()

# Perform the second part of the overall task: remove any remaining special characters from 'Last_Name'
df["Last_Name"] = df["Last_Name"].astype(str).str.replace(r'[^a-zA-Z\s]', '', regex=True).str.strip()

df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          nan
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         nan           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter          nan
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
import pandas as pd
import numpy as np


df = pd.read_excel('cleaning.xlsx')

# Convert known string representations of nulls to np.nan for consistent handling by dropna()
df.replace({'N/a': np.nan, 'nan': np.nan, '': np.nan}, inplace=True)

df = df.drop_duplicates()

# Apply existing Last_Name cleaning (strip / and . and leading/trailing whitespace)
df["Last_Name"] = df["Last_Name"].astype(str).str.strip("/. ")

# Apply Phone_Number cleaning
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("-", "" )
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("/", "" )
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("|", "" )

# Apply Do_Not_Contact cleaning
df["Do_Not_Contact"] = df["Do_Not_Contact"].astype(str).str.replace("Yes", "Y" )
df["Do_Not_Contact"] = df["Do_Not_Contact"].astype(str).str.replace("No", "N" )

# Apply Paying Customer cleaning
df["Paying Customer"] = df["Paying Customer"].astype(str).str.replace("Yes", "Y" )
df["Paying Customer"] = df["Paying Customer"].astype(str).str.replace("No", "N" )

# Perform the current subtask: remove all rows containing null values
df = df.dropna()

# Perform the second part of the overall task: remove any remaining special characters from 'Last_Name'
df["Last_Name"] = df["Last_Name"].astype(str).str.replace(r'[^a-zA-Z\s]', '', regex=True).str.strip()

df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          nan
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          nan
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         nan           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          nan
# 11        1012      Harry      Potter          nan
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('cleaning.xlsx')

# Convert known string representations of nulls to np.nan for consistent handling by dropna()
df.replace({'N/a': np.nan, 'nan': np.nan, '': np.nan}, inplace=True)

df = df.drop_duplicates()

# Perform the current subtask: remove all rows containing null values *before* other string operations
df = df.dropna()

# Apply existing Last_Name cleaning (strip / and . and leading/trailing whitespace)
df["Last_Name"] = df["Last_Name"].astype(str).str.strip("/. ")

# Apply Phone_Number cleaning
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("-", "" )
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("/", "" )
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("|", "" )

# Apply Do_Not_Contact cleaning
df["Do_Not_Contact"] = df["Do_Not_Contact"].astype(str).str.replace("Yes", "Y" )
df["Do_Not_Contact"] = df["Do_Not_Contact"].astype(str).str.replace("No", "N" )

# Apply Paying Customer cleaning
df["Paying Customer"] = df["Paying Customer"].astype(str).str.replace("Yes", "Y" )
df["Paying Customer"] = df["Paying Customer"].astype(str).str.replace("No", "N" )

# Perform the second part of the overall task: remove any remaining special characters from 'Last_Name'
df["Last_Name"] = df["Last_Name"].astype(str).str.replace(r'[^a-zA-Z\s]', '', regex=True).str.strip()

df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 7         1008   Sherlock      Holmes   8766783469
# 9         1010      Peter      Parker   1235455421
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 19        1020     Anakin   Skywalker   8766783469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire               Y              N
# 1                     93 West Main Street               N              Y
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('cleaning.xlsx')
# Convert known string representations of nulls to np.nan for consistent handling by dropna()
df.replace({'N/a': np.nan, 'nan': np.nan, 'NaN': np.nan, '': np.nan}, inplace=True)

df = df.drop_duplicates()

# Perform the current subtask: remove all rows containing null values *before* other string operations
df = df.dropna()
df = df.reset_index(drop=True)

# Apply existing Last_Name cleaning (strip / and . and leading/trailing whitespace)
df["Last_Name"] = df["Last_Name"].astype(str).str.strip("/. ")

# Apply Phone_Number cleaning
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("-", "" )
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("/", "" )
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace("|", "" )

# Apply Do_Not_Contact cleaning
df["Do_Not_Contact"] = df["Do_Not_Contact"].astype(str).str.replace("Yes", "Y" )
df["Do_Not_Contact"] = df["Do_Not_Contact"].astype(str).str.replace("No", "N" )

# Apply Paying Customer cleaning
df["Paying Customer"] = df["Paying Customer"].astype(str).str.replace("Yes", "Y" )
df["Paying Customer"] = df["Paying Customer"].astype(str).str.replace("No", "N" )

# Perform the second part of the overall task: remove any remaining special characters from 'Last_Name'
df["Last_Name"] = df["Last_Name"].astype(str).str.replace(r'[^a-zA-Z\s]', '', regex=True).str.strip()

df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1004     Dwight     Schrute   1235432345
# 3         1005        Jon        Snow   8766783469
# 4         1006        Ron     Swanson   3047622467
# 5         1008   Sherlock      Holmes   8766783469
# 6         1010      Peter      Parker   1235455421
# 7         1013        Don      Draper   1235432345
# 8         1014     Leslie       Knope   8766783469
# 9         1015       Toby  Flenderson   3047622467
# 10        1016        Ron     Weasley   1235455421
# 11        1017   Michael        Scott   1236439775
# 12        1020     Anakin   Skywalker   8766783469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire               Y              N
# 1                     93 West Main Street               N              Y
# ...

# %%
# Export cleaned Excel file
df.to_excel("cleaning.xlsx", index=False)

from google.colab import files
files.download("cleaning.xlsx")
